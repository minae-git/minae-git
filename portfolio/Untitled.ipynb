# %%
import requests as req

# %%
key = "baeea8dda3f947c68a164a47d5d9be8d"
return_type ='json'
p_index = 2
p_size = 50

# %%
gg_url = f"https://openapi.gg.go.kr/RegionMnyPublctUse?KEY={key}&Type={return_type}&pIndex={p_index}?pSize={p_size}"

# %%
gg_url
# Out:
# 'https://openapi.gg.go.kr/RegionMnyPublctUse?KEY=baeea8dda3f947c68a164a47d5d9be8d&Type=json&pIndex=2?pSize=50'

# %%
r1 = req.get(gg_url)
r1.status_code
# Out:
# 200

# %%
len(r1.json()['RegionMnyPublctUse'][1]['row'])
# Out:
# 100

# %%
r2 = req.get(gg_url)
r2.status_code
# Out:
# 200

# %%
r2.json()
# Out:
# {'RegionMnyPublctUse': [{'head': [{'list_total_count': 465},
#     {'RESULT': {'CODE': 'INFO-000', 'MESSAGE': '정상 처리되었습니다.'}},
#     {'api_version': '1.0'}]},
#   {'row': [{'SIGUN_CD': '41650',
#      'SIGUN_NM': '포천시',
#      'STD_YM': '2019-11',
#      'CARD_PUBLCT_CNT': 144,
#      'CARD_CHRGNG_AMT': 48250,
#      'CARD_USE_AMT': 178419,
#      'MOBILE_GIFTCERTF_USER_CNT': None,
#      'MOBILE_CHRGNG_AMT': None,
#      'MOBILE_USE_AMT': None,
#      'BRNHSTRM_GIFTCERTF_SALE_AMT': 191300,
#      'BRNHSTRM_GIFTCERTF_RETRVL_AMT': 114730},
#     {'SIGUN_CD': '41430',
#      'SIGUN_NM': '의왕시',
#      'STD_YM': '2019-11',
#      'CARD_PUBLCT_CNT': 150,
#      'CARD_CHRGNG_AMT': 54250,
#      'CARD_USE_AMT': 231644,
#      'MOBILE_GIFTCERTF_USER_CNT': None,
#      'MOBILE_CHRGNG_AMT': None,
#      'MOBILE_USE_AMT': None,
#      'BRNHSTRM_GIFTCERTF_SALE_AMT': 266255,
#      'BRNHSTRM_GIFTCERTF_RETRVL_AMT': 341145},
#     {'SIGUN_CD': '41830',
#      'SIGUN_NM': '양평군',
# ...
